# %% [markdown]
# <a href="https://colab.research.google.com/github/Jagriti1891/JAGRITI-BALLA/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {
    "Date": [
        "2024-01-05", "2024-01-15",
        "2024-02-10", "2024-02-18",
        "2024-03-05", "2024-03-20",
        "2024-04-08", "2024-04-25"
    ],
    "Sales": [1200, 1500, 1800, 1600, 2200, 2100, 1700, 1900]
}

df = pd.DataFrame(data)
df
# Out:
#          Date  Sales
# 0  2024-01-05   1200
# 1  2024-01-15   1500
# 2  2024-02-10   1800
# 3  2024-02-18   1600
# 4  2024-03-05   2200
# 5  2024-03-20   2100
# 6  2024-04-08   1700
# 7  2024-04-25   1900

# %%
df["Date"] = pd.to_datetime(df["Date"])
df
# Out:
#         Date  Sales
# 0 2024-01-05   1200
# 1 2024-01-15   1500
# 2 2024-02-10   1800
# 3 2024-02-18   1600
# 4 2024-03-05   2200
# 5 2024-03-20   2100
# 6 2024-04-08   1700
# 7 2024-04-25   1900

# %%
df["Month"] = df["Date"].dt.month_name()
df
# Out:
#         Date  Sales     Month
# 0 2024-01-05   1200   January
# 1 2024-01-15   1500   January
# 2 2024-02-10   1800  February
# 3 2024-02-18   1600  February
# 4 2024-03-05   2200     March
# 5 2024-03-20   2100     March
# 6 2024-04-08   1700     April
# 7 2024-04-25   1900     April

# %%
monthly_sales = df.groupby("Month")["Sales"].sum()
monthly_sales
# Out:
# Month
# April       3600
# February    3400
# January     2700
# March       4300
# Name: Sales, dtype: int64

# %%
monthly_sales = df.groupby("Month")["Sales"].sum()
monthly_sales
# Out:
# Month
# April       3600
# February    3400
# January     2700
# March       4300
# Name: Sales, dtype: int64

# %%
best_month = monthly_sales.idxmax()
worst_month = monthly_sales.idxmin()

print("Best Sales Month:", best_month)
print("Worst Sales Month:", worst_month)
# Out:
# Best Sales Month: March
# Worst Sales Month: January

# %%
plt.figure(figsize=(8,5))
monthly_sales.plot(marker="o")

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.grid(True)
plt.show()
